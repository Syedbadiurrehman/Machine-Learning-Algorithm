# %% [markdown]
# <a href="https://colab.research.google.com/github/Syedbadiurrehman/Machine-Learning-Algorithm/blob/main/Multiple_Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('/content/sample_data/anscombe.json')
print(df)
# Out:
#                                         [
#   {"Series":"I"   "X":10.0 "Y":8.04}  NaN
#                   "X":8.0  "Y":6.95}  NaN
#                   "X":13.0 "Y":7.58}  NaN
#                   "X":9.0  "Y":8.81}  NaN
#                   "X":11.0 "Y":8.33}  NaN
#                   "X":14.0 "Y":9.96}  NaN
#                   "X":6.0  "Y":7.24}  NaN
#                   "X":4.0  "Y":4.26}  NaN
#                   "X":12.0 "Y":10.84} NaN
#                   "X":7.0  "Y":4.81}  NaN
#                   "X":5.0  "Y":5.68}  NaN
#   {"Series":"II"  "X":10.0 "Y":9.14}  NaN
#                   "X":8.0  "Y":8.14}  NaN
#                   "X":13.0 "Y":8.74}  NaN
#                   "X":9.0  "Y":8.77}  NaN
#                   "X":11.0 "Y":9.26}  NaN
#                   "X":14.0 "Y":8.10}  NaN
#                   "X":6.0  "Y":6.13}  NaN
#                   "X":4.0  "Y":3.10}  NaN
#                   "X":12.0 "Y":9.13}  NaN
#                   "X":7.0  "Y":7.26}  NaN
# ...

# %%
rows = len(df['Hours Studied'])
print(rows)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Hours Studied'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-1031292040.py in <cell line: 0>()
# ----> 1 rows = len(df['Hours Studied'])
#       2 print(rows)
#
# ...

# %%
col = len(df.columns)
print(col)

# %%
import numpy as np
median_value = np.median(df['Hours Studied'])
print(median_value)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-4106944267.py in <cell line: 0>()
#       1 import numpy as np
# ----> 2 median_value = np.median(df['Hours Studied'])
#       3 print(median_value)
#
# NameError: name 'df' is not defined
