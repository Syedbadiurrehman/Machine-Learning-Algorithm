# %% [markdown]
# <a href="https://colab.research.google.com/github/Syedbadiurrehman/Machine-Learning-Algorithm/blob/main/Datavisualizationwithpandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_csv('/Salary_dataset.csv')
print(df)
# Out:
#     Unnamed: 0  YearsExperience    Salary
# 0            0              1.2   39344.0
# 1            1              1.4   46206.0
# 2            2              1.6   37732.0
# 3            3              2.1   43526.0
# 4            4              2.3   39892.0
# 5            5              3.0   56643.0
# 6            6              3.1   60151.0
# 7            7              3.3   54446.0
# 8            8              3.3   64446.0
# 9            9              3.8   57190.0
# 10          10              4.0   63219.0
# 11          11              4.1   55795.0
# 12          12              4.1   56958.0
# 13          13              4.2   57082.0
# 14          14              4.6   61112.0
# 15          15              5.0   67939.0
# 16          16              5.2   66030.0
# 17          17              5.4   83089.0
# 18          18              6.0   81364.0
# 19          19              6.1   93941.0
# 20          20              6.9   91739.0
# ...

# %%
df.plot()
# Out:
# <Axes: >

# %%
df.plot.line()
# Out:
# <Axes: >

# %%
df.plot.scatter('YearsExperience' , 'Salary')
# Out:
# <Axes: xlabel='YearsExperience', ylabel='Salary'>

# %%
df.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.plot.area()
# Out:
# <Axes: >

# %%
df.plot.bar()
# Out:
# <Axes: >

# %%
df.plot.barh()
# Out:
# <Axes: >

# %%
df.plot.box()
# Out:
# <Axes: >

# %%
df.plot.hexbin('YearsExperience', 'Salary')
# Out:
# <Axes: xlabel='YearsExperience', ylabel='Salary'>

# %%
df.plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %%
df.plot.pie(x='YearsExperience', y='Salary')
# Out:
# <Axes: ylabel='Salary'>

# %%
df.plot()
plt.savefig('plot.png')
